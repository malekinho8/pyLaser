# %%
import sys; sys.path.append('../')
from utils import *

# %%
# define setup variables
laser_azimuth = 120
laser_polar = 150
mirror_roll = 0
mirror_pitch = -11
mirror_yaw = 0

# %%
# call main function
run(laser_azimuth, laser_polar, mirror_roll, mirror_pitch, mirror_yaw)
# Out:
# Reflected Vector Azimuth: 142.0992751157615 degrees
# Reflected Vector Polar: 44.82094336824411 degrees
